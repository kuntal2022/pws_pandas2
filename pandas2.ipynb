# %% [markdown]
# # Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd
#read a data
inp0=pd.read_csv(r"C:\Users\Neel\Desktop\Sales\Test.csv")

# %%
# no.1 shape
inp0.shape
# Out:
# (5681, 11)

# %%
#no 2. info
inp0.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 2.6 MB

# %%
#no 3: describe
inp0.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
# no 4: find nan value
inp0.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
# no5. drop dublicates
inp0.drop_duplicates()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %% [markdown]
# # Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
# creating a data frame inp1 from inp0
inp1=inp0.iloc[:, 0:3]
inp1.columns=["A", "B", "C"] # creating the A,B,C columns
inp1.head(10) # printing 10 rows to check the order
# Out:
#        A       B        C
# 0  FDW58  20.750  Low Fat
# 1  FDW14   8.300      reg
# 2  NCN55  14.600  Low Fat
# 3  FDQ58   7.315  Low Fat
# 4  FDY38     NaN  Regular
# 5  FDH56   9.800  Regular
# 6  FDL48  19.350  Regular
# 7  FDC48     NaN  Low Fat
# 8  FDN33   6.305  Regular
# 9  FDA36   5.985  Low Fat

# %%
inp1.reindex([i for i in range(1,len(inp1.A),2)]) # re indexing with new index that get increase with 2 number
# Out:
#           A       B        C
# 1     FDW14   8.300      reg
# 3     FDQ58   7.315  Low Fat
# 5     FDH56   9.800  Regular
# 7     FDC48     NaN  Low Fat
# 9     FDA36   5.985  Low Fat
# ...     ...     ...      ...
# 5671  FDA01  15.000      reg
# 5673  FDF46   7.070  Low Fat
# 5675  FDW46  13.000  Regular
# 5677  FDD47   7.600  Regular
# 5679  FDJ26  15.300  Regular
#
# [2840 rows x 3 columns]

# %% [markdown]
# # Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The function should print the sum to the console. For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should calculate and print the sum of the first three values, which is 60.

# %%
# creating the dataframe

df=pd.DataFrame({"Product":["a", 'b', 'c', 'd', 'e'], "Value":[10,20,30,40,50]})
df
# Out:
#   Product  Value
# 0       a     10
# 1       b     20
# 2       c     30
# 3       d     40
# 4       e     50

# %%
def first_3(Value): # creation of the function
    return df['Value'][:3].sum() # using iloc for 3 rows and sum to add the values
first_3("Value") # calling the function
# Out:
# 60

# %% [markdown]
# # Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
#creation of the df

df=pd.DataFrame({"Text":["hello how are you", "this is a pandas", "this is python and we are learning python and pandas", 
                       "how the world is beautifull"]})

df
# Out:
#                                                 Text
# 0                                  hello how are you
# 1                                   this is a pandas
# 2  this is python and we are learning python and ...
# 3                        how the world is beautifull

# %%
Word_count=df.Text.apply(lambda x: len(x.split())) # creating the var word_count with len of spliting words
df['Word_count']=Word_count # creating the new col
df
# Out:
#                                                 Text  Word_count
# 0                                  hello how are you           4
# 1                                   this is a pandas           4
# 2  this is python and we are learning python and ...          10
# 3                        how the world is beautifull           5

# %% [markdown]
# # Q5. How are DataFrame.size() and DataFrame.shape() different?
#
# # ANS
#
# #### size
# * Syntax: dataframe.size
# * Return : Returns size of dataframe/series which is equivalent to total number of elements. That is rows x columns.
# #### shape
# * Syntax: dataframe.shape
# * Return : Returns tuple of shape (Rows, columns) of dataframe/series

# %%
print(f"shape is {inp0.shape}")
print(f"Size is {inp0.size}")
# Out:
# shape is (5681, 11)
# Size is 62491

# %% [markdown]
# # Q6. Which function of pandas do we use to read an excel file?
#
# ##### ANS:
# pd.read_excel()

# %%
# exmp

pd.read_excel(r"C:\Users\Neel\Desktop\RSA Activity Monthwise_2023.xlsx").fillna(0).tail()
# Out:
#            RSA Name       Reporting To      HQ Month  \
# 38  Swapna Chudhari  Mr Raghavendra MR    Pune   Feb
# 39  Swapna Chudhari  Mr Raghavendra MR    Pune   Feb
# 40  Swapna Chudhari  Mr Raghavendra MR    Pune   Feb
# 41  Swapna Chudhari  Mr Raghavendra MR    Pune   Feb
# 42  Abhishek Pathak  Mr Raghavendra MR  Mumbai     0
#
#                      Account Name            Veeva ID Segment  \
# 38  Sahyadri Hospital, Nagar Road  0019000001nyekWAAQ   Build
# 39             Jahangeer Hospital  0019000001nyek5AAA    Gain
# 40             Jahangeer Hospital  0019000001nyek5AAA    Gain
# 41                Oriion Citicare  0019000001nyej5AA5   build
# 42                              0                   0       0
#
#                    Event     Event_Specific_name        Proposed Date  \
# 38  Preceptorship Program  Preceptorship Program  2023-02-26 00:00:00
# 39       Refferal Meeting       Refferal Meeting  2023-02-25 00:00:00
# ...

# %% [markdown]
# # Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email addresses in the format 'username@domain.com'. Write a Python function that creates a new column 'Username' in df that contains only the username part of each email address. The username is the part of the email address that appears before the '@' symbol. For example, if the email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your function should extract the username from each email address and store it in the new 'Username' column.

# %%
# creating the dataframe

df=pd.DataFrame({"Email":["ram.mohan@gmail.com", "shyam.raju@gmail.com", "sita.mata@gmail.com", "krishna.treta@gmail.com"]})
df
# Out:
#                      Email
# 0      ram.mohan@gmail.com
# 1     shyam.raju@gmail.com
# 2      sita.mata@gmail.com
# 3  krishna.treta@gmail.com

# %%
Username=df.Email.apply(lambda x: x.split("@")[0]) # creation of the function to extract the username only
df["Username"]=Username # creating the new col Username
df
# Out:
#                      Email       Username
# 0      ram.mohan@gmail.com      ram.mohan
# 1     shyam.raju@gmail.com     shyam.raju
# 2      sita.mata@gmail.com      sita.mata
# 3  krishna.treta@gmail.com  krishna.treta

# %% [markdown]
# # Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The function should return a new DataFrame that contains only the selected rows. For example, if df contains the following values:
#
# ![image.png](attachment:image.png)
#
# # Your function should select the following rows:
# # A B C
# # 1 8 2 7
# # 4 9 1 2
# #
# # The function should return a new DataFrame that contains only the selected rows.

# %%
#creation of df

df=pd.DataFrame({"A":[3,8,6,2,9],
                "B": [5,2,9,3,1],
                "C":[1,7,4,5,2]}
                   )
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
df[(df.A>5) & (df.B<10)] # filtering the data
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# # Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,median, and standard deviation of the values in the 'Values' column.

# %%
# creation of dataframe

df=pd.DataFrame({"P":["a","b","c","d","e","f","g","h"],
    "Value":[112,223,453,324,89,101,65,3000 ]})
df
# Out:
#    P  Value
# 0  a    112
# 1  b    223
# 2  c    453
# 3  d    324
# 4  e     89
# 5  f    101
# 6  g     65
# 7  h   3000

# %%
# method 1
def description_x(col):
    
    print(f"Mean = {df[col].mean()}")
    print(f"Median = {df[col].median()}")
    print(f"Standard deviation = {df[col].std()}")

# %%
description_x("Value")
# Out:
# Mean = 545.875
# Median = 167.5
# Standard deviation = 1000.7831843825401

# %% [markdown]
# # Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days for each row in the DataFrame. The moving average should be calculated using a window of size 7 and should include the current day.

# %%
import warnings
warnings.filterwarnings('ignore')

# Creating the DataFrame
df = pd.DataFrame({'Date':['10/2/2023', '11/2/2023', '12/2/2023', '13/2/2023',\
                           "14/02/2023",'10/2/2023', '11/2/2023', '12/12/2022', '03/1/2023',"14/12/2022"],\
                   
                    'Sales':[10000, 5000, 15000, 2000,2000,3000,1000,2435,6000,1200]})
 
# Print the dataframe
print(df)
print("#############################################################")
#get the moving average
df.Date=pd.to_datetime(df.Date)
df.set_index(df.Date, inplace=True) # setting date col as index

print()

print("Moving Average")


round(df.Sales.rolling(window=7).mean().fillna(0),2) # round to 2 decimal values with 0 value for fill na
# Out:
#          Date  Sales
# 0   10/2/2023  10000
# 1   11/2/2023   5000
# 2   12/2/2023  15000
# 3   13/2/2023   2000
# 4  14/02/2023   2000
# 5   10/2/2023   3000
# 6   11/2/2023   1000
# 7  12/12/2022   2435
# 8   03/1/2023   6000
# 9  14/12/2022   1200
# #############################################################
#
# Moving Average
# Date
# 2023-10-02       0.00
# 2023-11-02       0.00
# 2023-12-02       0.00
# 2023-02-13       0.00
# 2023-02-14       0.00
# 2023-10-02       0.00
# 2023-11-02    5428.57
# 2022-12-12    4347.86
# 2023-03-01    4490.71
# 2022-12-14    2519.29
# Name: Sales, dtype: float64

# %% [markdown]
# # Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.Monday, Tuesday) corresponding to each date in the 'Date' column.For example, if df contains the following values:
#
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %%
#creating the df

df=pd.DataFrame({'Date':["2023-01-01","2023-01-02"
, "2023-01-03"
, "2023-01-04"
, "2023-01-05"]})

# creating the weekday col

df["Weekday"]=pd.to_datetime(df.Date).dt.strftime("%A")
df
# Out:
#          Date    Weekday
# 0  2023-01-01     Sunday
# 1  2023-01-02     Monday
# 2  2023-01-03    Tuesday
# 3  2023-01-04  Wednesday
# 4  2023-01-05   Thursday

# %% [markdown]
# # Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
#creation of df
df=pd.DataFrame({'Date':["2023-01-01","2023-01-02","2022-01-01"
, "2023-01-03"
, "2023-01-04"
, "2023-01-05","2023-01-31",
                        "2023-01-03"
, "2023-01-04"
, "2023-01-05"]})
df
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2022-01-01
# 3  2023-01-03
# 4  2023-01-04
# 5  2023-01-05
# 6  2023-01-31
# 7  2023-01-03
# 8  2023-01-04
# 9  2023-01-05

# %%
# changing the col date to timesamp
df.Date=pd.to_datetime(df.Date)

#filtering required data 
df[(df.Date>='2023-01-01') & (df.Date<="2023-01-31")].sort_values("Date", ascending=True)
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-02
# 3 2023-01-03
# 7 2023-01-03
# 4 2023-01-04
# 8 2023-01-04
# 5 2023-01-05
# 9 2023-01-05
# 6 2023-01-31

# %% [markdown]
# # Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to be imported?
#
#
# # ANS
# * We need to import pandas
#
# #### Syntax
# > import pandas as pd
